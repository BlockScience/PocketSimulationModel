# %%
import os
import pandas as pd
os.chdir("..")
from utilities import prepare_quantiles,plot_quantiles

# %% [markdown]
# All sanity checks here use a sample of 20 parameter constellations with 5 monte carlo runs.

# %% [markdown]
# ## Network Failures Service Adaptive Grid 1

# %%
q = prepare_quantiles("simulation_data/network_failures_service_ag1_MC.csv")
plot_quantiles(q, 3)

# %% [markdown]
# ## Gateway Viability Adaptive Grid 1

# %%
q = prepare_quantiles("simulation_data/gateway_viability_sweep_ag1_mc.csv")
plot_quantiles(q, 3)

# %% [markdown]
# ## Network Failures Oracle Adaptive Grid 1

# %%
q = prepare_quantiles("simulation_data/network_failures_oracle_ag1_MC.csv")
plot_quantiles(q, 3)
# Out:
# /Users/seanmcowen/Dropbox/BlockScience/PocketSimulationModel/utilities.py:5: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(simulation_data_path, index_col = 0)

# %% [markdown]
# ## Servicer Viability Adaptive Grid 1

# %%
q = prepare_quantiles("simulation_data/servicer_viability_ag1_MC.csv")
plot_quantiles(q, 3)

# %% [markdown]
# ## Network Viability Adaptive Grid 1

# %%
q = prepare_quantiles("simulation_data/network_viability_ag1_MC.csv")
plot_quantiles(q, 3)

# %% [markdown]
# ## Network Failures Service Adaptive Grid 1
