# %% [markdown]
# # Parameter Impact on KPIs

# %%
import os
os.chdir("..")

# %%
scenario_sweep_category = 'network_failures_service_ag'

# %%
from psuu.parameter_impact_plots import *
merged_df = read_and_format_data(scenario_sweep_category = scenario_sweep_category)

# %%
import numpy as np
np.unique(merged_df['AG iteration'].values)
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %% [markdown]
# ### Slash Fraction Downtime

# %%
SFD_param_impact_plot = make_initial_vs_final_plot(df = merged_df,
                           scenario_sweep_category = scenario_sweep_category,
                           param_name = "param_slash_fraction_downtime")

# %% [markdown]
# ### Max Chains Per Servicer

# %%
MCPS_param_impact_plot = make_initial_vs_final_plot(df = merged_df,
                           scenario_sweep_category = scenario_sweep_category,
                           param_name = "param_max_chains_servicer")
